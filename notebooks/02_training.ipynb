# %% [markdown]
# # CIFAR-10 Classifier with CNN

# %% [markdown]
# ### Imports & Setup

# %%
import random
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split, Subset

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
import os, json

RESULTS_DIR = "results"
MODELS_DIR = "models"
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(MODELS_DIR, exist_ok=True)

# %% [markdown]
# ### Dataset and Dataloader Setup

# %%
MEAN = (0.4914, 0.4822, 0.4465)
STD  = (0.2023, 0.1994, 0.2010)

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD)
])

full_train_aug = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform_train
)

full_train_clean = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform_test
)

train_size = int(0.9 * len(full_train_aug))
val_size = len(full_train_aug) - train_size
train_split, val_split = random_split(full_train_aug, [train_size, val_size])

train_ds = Subset(full_train_aug, train_split.indices)
val_ds   = Subset(full_train_clean, val_split.indices)

test_ds = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform_test
)

class_names = [
    "airplane","automobile","bird","cat","deer",
    "dog","frog","horse","ship","truck"
]
# Out:
# 100.0%

# %%
def make_loaders(batch_size: int):
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)
    return train_loader, val_loader, test_loader

# %% [markdown]
# ### CNN Model

# %%
class SimpleCNN(nn.Module):
    def __init__(self, dropout: float = 0.2):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1   = nn.BatchNorm2d(32)

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2   = nn.BatchNorm2d(64)

        self.pool  = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1   = nn.Linear(64 * 8 * 8, 256)
        self.drop  = nn.Dropout(dropout)
        self.fc2   = nn.Linear(256, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.bn1(self.conv1(x))))
        x = self.pool(torch.relu(self.bn2(self.conv2(x))))

        x = x.view(x.size(0), -1)

        x = torch.relu(self.fc1(x))
        x = self.drop(x)
        x = self.fc2(x)
        
        return x

# %% [markdown]
# ### Training Utilities

# %% [markdown]
# **Training & Validation One Epoch**

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad(set_to_none=True)
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total


@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * images.size(0)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total

# %% [markdown]
# **Training Multiple Epochs & Tracking**

# %%
def fit(model, train_loader, val_loader, criterion, optimizer, device, epochs: int):
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []

    best_val_acc = -1.0
    best_state = None

    for epoch in range(epochs):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
        va_loss, va_acc = evaluate(model, val_loader, criterion, device)

        train_losses.append(tr_loss)
        val_losses.append(va_loss)
        train_accs.append(tr_acc)
        val_accs.append(va_acc)

        if va_acc > best_val_acc:
            best_val_acc = va_acc
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        print(
            f"Epoch {epoch+1}/{epochs} | "
            f"Train Loss: {tr_loss:.4f}, Train Acc: {tr_acc:.4f} | "
            f"Val Loss: {va_loss:.4f}, Val Acc: {va_acc:.4f}"
        )

    return {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "train_accs": train_accs,
        "val_accs": val_accs,
        "best_val_acc": best_val_acc,
        "best_state": best_state
    }

# %% [markdown]
# **Plotting Training Curves**

# %%
def plot_curves(history):
    plt.figure()
    plt.plot(history["train_losses"], label="Train Loss")
    plt.plot(history["val_losses"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss Curve")
    plt.show()

    plt.figure()
    plt.plot(history["train_accs"], label="Train Acc")
    plt.plot(history["val_accs"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy Curve")
    plt.show()

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# **Experiment Function**

# %%
def run_experiment(lr, batch_size, dropout, epochs, device):
    train_loader, val_loader, _ = make_loaders(batch_size)

    model = SimpleCNN(dropout=dropout).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    history = fit(model, train_loader, val_loader, criterion, optimizer, device, epochs)

    return {
        "lr": lr,
        "batch_size": batch_size,
        "dropout": dropout,
        "best_val_acc": history["best_val_acc"],
        "best_state": history["best_state"]
    }

# %% [markdown]
# **Tuning Grid Loop & Results Table**

# %%
lrs = [1e-2, 1e-3, 1e-4]
batch_sizes = [32, 64]
dropouts = [0.2, 0.5]
EPOCHS_TUNE = 10

results = []
best_run = None

for lr in lrs:
    for bs in batch_sizes:
        for do in dropouts:
            out = run_experiment(lr, bs, do, EPOCHS_TUNE, device)
            results.append({
                "lr": out["lr"],
                "batch_size": out["batch_size"],
                "dropout": out["dropout"],
                "best_val_acc": out["best_val_acc"]
            })

            if (best_run is None) or (out["best_val_acc"] > best_run["best_val_acc"]):
                best_run = out

df_results = pd.DataFrame(results).sort_values(by="best_val_acc", ascending=False)
df_results
# Out:
# Epoch 7/10 | Train Loss: 1.2407, Train Acc: 0.5546 | Val Loss: 0.9797, Val Acc: 0.6612
# Epoch 8/10 | Train Loss: 1.2080, Train Acc: 0.5666 | Val Loss: 0.9236, Val Acc: 0.6684
# Epoch 9/10 | Train Loss: 1.1902, Train Acc: 0.5753 | Val Loss: 0.8913, Val Acc: 0.6776
# Epoch 10/10 | Train Loss: 1.1671, Train Acc: 0.5840 | Val Loss: 0.9004, Val Acc: 0.6796
# Epoch 1/10 | Train Loss: 1.5864, Train Acc: 0.4261 | Val Loss: 1.2530, Val Acc: 0.5548
# Epoch 2/10 | Train Loss: 1.2973, Train Acc: 0.5319 | Val Loss: 1.1046, Val Acc: 0.6116
# Epoch 3/10 | Train Loss: 1.1987, Train Acc: 0.5698 | Val Loss: 1.0210, Val Acc: 0.6478
# Epoch 4/10 | Train Loss: 1.1322, Train Acc: 0.5964 | Val Loss: 0.9625, Val Acc: 0.6626
# Epoch 5/10 | Train Loss: 1.0922, Train Acc: 0.6091 | Val Loss: 0.9384, Val Acc: 0.6706
# Epoch 6/10 | Train Loss: 1.0535, Train Acc: 0.6276 | Val Loss: 0.9100, Val Acc: 0.6754
# Epoch 7/10 | Train Loss: 1.0201, Train Acc: 0.6364 | Val Loss: 0.8867, Val Acc: 0.6808
# Epoch 8/10 | Train Loss: 0.9938, Train Acc: 0.6494 | Val Loss: 0.8606, Val Acc: 0.6932
# Epoch 9/10 | Train Loss: 0.9693, Train Acc: 0.6553 | Val Loss: 0.8312, Val Acc: 0.7056
# Epoch 10/10 | Train Loss: 0.9484, Train Acc: 0.6642 | Val Loss: 0.8313, Val Acc: 0.7040
# Epoch 1/10 | Train Loss: 1.7177, Train Acc: 0.3695 | Val Loss: 1.3539, Val Acc: 0.5176
# Epoch 2/10 | Train Loss: 1.4613, Train Acc: 0.4701 | Val Loss: 1.2147, Val Acc: 0.5680
# Epoch 3/10 | Train Loss: 1.3500, Train Acc: 0.5120 | Val Loss: 1.1236, Val Acc: 0.6100
# Epoch 4/10 | Train Loss: 1.2797, Train Acc: 0.5408 | Val Loss: 1.0761, Val Acc: 0.6252
# Epoch 5/10 | Train Loss: 1.2318, Train Acc: 0.5607 | Val Loss: 1.0106, Val Acc: 0.6476
# Epoch 6/10 | Train Loss: 1.1956, Train Acc: 0.5756 | Val Loss: 0.9846, Val Acc: 0.6524
# Epoch 7/10 | Train Loss: 1.1657, Train Acc: 0.5842 | Val Loss: 0.9656, Val Acc: 0.6572
# Epoch 8/10 | Train Loss: 1.1360, Train Acc: 0.5947 | Val Loss: 0.9427, Val Acc: 0.6766
# Epoch 9/10 | Train Loss: 1.1171, Train Acc: 0.6020 | Val Loss: 0.9308, Val Acc: 0.6700
# Epoch 10/10 | Train Loss: 1.1023, Train Acc: 0.6082 | Val Loss: 0.9021, Val Acc: 0.6826
# Epoch 1/10 | Train Loss: 1.6520, Train Acc: 0.3981 | Val Loss: 1.3320, Val Acc: 0.5244
# Epoch 2/10 | Train Loss: 1.3601, Train Acc: 0.5121 | Val Loss: 1.1576, Val Acc: 0.5918
# Epoch 3/10 | Train Loss: 1.2420, Train Acc: 0.5571 | Val Loss: 1.0666, Val Acc: 0.6196
# Epoch 4/10 | Train Loss: 1.1695, Train Acc: 0.5841 | Val Loss: 1.0105, Val Acc: 0.6448
# Epoch 5/10 | Train Loss: 1.1136, Train Acc: 0.6034 | Val Loss: 0.9859, Val Acc: 0.6468
# Epoch 6/10 | Train Loss: 1.0805, Train Acc: 0.6187 | Val Loss: 0.9240, Val Acc: 0.6766
# Epoch 7/10 | Train Loss: 1.0481, Train Acc: 0.6290 | Val Loss: 0.9054, Val Acc: 0.6872
# Epoch 8/10 | Train Loss: 1.0143, Train Acc: 0.6416 | Val Loss: 0.8935, Val Acc: 0.6872
# Epoch 9/10 | Train Loss: 0.9940, Train Acc: 0.6516 | Val Loss: 0.8766, Val Acc: 0.6966
# Epoch 10/10 | Train Loss: 0.9700, Train Acc: 0.6588 | Val Loss: 0.8555, Val Acc: 0.7034
# Epoch 1/10 | Train Loss: 1.7328, Train Acc: 0.3672 | Val Loss: 1.4106, Val Acc: 0.4874
# Epoch 2/10 | Train Loss: 1.4664, Train Acc: 0.4704 | Val Loss: 1.2266, Val Acc: 0.5626
# Epoch 3/10 | Train Loss: 1.3590, Train Acc: 0.5090 | Val Loss: 1.1478, Val Acc: 0.5996
# Epoch 4/10 | Train Loss: 1.2908, Train Acc: 0.5346 | Val Loss: 1.0915, Val Acc: 0.6158
# Epoch 5/10 | Train Loss: 1.2416, Train Acc: 0.5572 | Val Loss: 1.0341, Val Acc: 0.6312
# Epoch 6/10 | Train Loss: 1.2025, Train Acc: 0.5715 | Val Loss: 1.0020, Val Acc: 0.6436
# Epoch 7/10 | Train Loss: 1.1673, Train Acc: 0.5875 | Val Loss: 0.9761, Val Acc: 0.6508
# Epoch 8/10 | Train Loss: 1.1416, Train Acc: 0.5958 | Val Loss: 0.9496, Val Acc: 0.6614
# Epoch 9/10 | Train Loss: 1.1219, Train Acc: 0.6020 | Val Loss: 0.9277, Val Acc: 0.6686
# Epoch 10/10 | Train Loss: 1.1015, Train Acc: 0.6102 | Val Loss: 0.9249, Val Acc: 0.6674
#         lr  batch_size  dropout  best_val_acc
# 6   0.0010          64      0.2        0.7270
# 4   0.0010          32      0.2        0.7262
# 8   0.0001          32      0.2        0.7056
# 10  0.0001          64      0.2        0.7034
# 5   0.0010          32      0.5        0.6834
# 9   0.0001          32      0.5        0.6826
# 7   0.0010          64      0.5        0.6796
# 11  0.0001          64      0.5        0.6686
# 2   0.0100          64      0.2        0.5970
# 0   0.0100          32      0.2        0.5690
# 1   0.0100          32      0.5        0.4970
# 3   0.0100          64      0.5        0.4800

# %% [markdown]
# **Save tuning CSV**

# %%
df_results.to_csv(f"{RESULTS_DIR}/tuning_results.csv", index=False)
print("Saved:", f"{RESULTS_DIR}/tuning_results.csv")
# Out:
# Saved: results/tuning_results.csv

# %% [markdown]
# **Save best_config.json**

# %%
best_row = df_results.iloc[0].to_dict()

best_config = {
    "lr": float(best_row["lr"]),
    "batch_size": int(best_row["batch_size"]),
    "dropout": float(best_row["dropout"]),
    "best_val_acc": float(best_row["best_val_acc"])
}

with open(f"{RESULTS_DIR}/best_config.json", "w") as f:
    json.dump(best_config, f, indent=2)

print("Saved:", f"{RESULTS_DIR}/best_config.json")
best_config
# Out:
# Saved: results/best_config.json
# {'lr': 0.001, 'batch_size': 64, 'dropout': 0.2, 'best_val_acc': 0.727}

# %% [markdown]
# ### Final Training

# %%
BEST_LR = float(best_run["lr"])
BEST_BS = int(best_run["batch_size"])
BEST_DO = float(best_run["dropout"])

print("Best config:", {"lr": BEST_LR, "batch_size": BEST_BS, "dropout": BEST_DO})

train_loader, val_loader, test_loader = make_loaders(BEST_BS)

model = SimpleCNN(dropout=BEST_DO).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=BEST_LR)

EPOCHS_FINAL = 30
history = fit(model, train_loader, val_loader, criterion, optimizer, device, EPOCHS_FINAL)

model.load_state_dict(history["best_state"])
model.to(device)

plot_curves(history)
print("Best Val Acc:", history["best_val_acc"])


plt.savefig(f"{RESULTS_DIR}/training_curves.png", dpi=200, bbox_inches="tight")
plt.show()

print("Saved:", f"{RESULTS_DIR}/training_curves.png")
# Out:
# Best config: {'lr': 0.001, 'batch_size': 64, 'dropout': 0.2}
# Epoch 1/30 | Train Loss: 1.5753, Train Acc: 0.4250 | Val Loss: 1.1955, Val Acc: 0.5708
# Epoch 2/30 | Train Loss: 1.2827, Train Acc: 0.5358 | Val Loss: 1.0707, Val Acc: 0.6044
# Epoch 3/30 | Train Loss: 1.1930, Train Acc: 0.5728 | Val Loss: 0.9878, Val Acc: 0.6468
# Epoch 4/30 | Train Loss: 1.1293, Train Acc: 0.5980 | Val Loss: 0.9501, Val Acc: 0.6710
# Epoch 5/30 | Train Loss: 1.0781, Train Acc: 0.6163 | Val Loss: 0.8809, Val Acc: 0.6864
# Epoch 6/30 | Train Loss: 1.0433, Train Acc: 0.6308 | Val Loss: 0.9113, Val Acc: 0.6820
# Epoch 7/30 | Train Loss: 1.0153, Train Acc: 0.6428 | Val Loss: 0.8842, Val Acc: 0.6818
# Epoch 8/30 | Train Loss: 0.9888, Train Acc: 0.6479 | Val Loss: 0.8167, Val Acc: 0.7110
# Epoch 9/30 | Train Loss: 0.9721, Train Acc: 0.6568 | Val Loss: 0.8075, Val Acc: 0.7118
# Epoch 10/30 | Train Loss: 0.9393, Train Acc: 0.6696 | Val Loss: 0.7773, Val Acc: 0.7276
# Epoch 11/30 | Train Loss: 0.9243, Train Acc: 0.6746 | Val Loss: 0.7816, Val Acc: 0.7196
# Epoch 12/30 | Train Loss: 0.9061, Train Acc: 0.6806 | Val Loss: 0.7912, Val Acc: 0.7198
# Epoch 13/30 | Train Loss: 0.8931, Train Acc: 0.6856 | Val Loss: 0.7718, Val Acc: 0.7208
# Epoch 14/30 | Train Loss: 0.8726, Train Acc: 0.6927 | Val Loss: 0.7414, Val Acc: 0.7354
# Epoch 15/30 | Train Loss: 0.8583, Train Acc: 0.6974 | Val Loss: 0.8227, Val Acc: 0.7140
# Epoch 16/30 | Train Loss: 0.8521, Train Acc: 0.7026 | Val Loss: 0.7359, Val Acc: 0.7418
# Epoch 17/30 | Train Loss: 0.8409, Train Acc: 0.7062 | Val Loss: 0.7259, Val Acc: 0.7486
# Epoch 18/30 | Train Loss: 0.8292, Train Acc: 0.7098 | Val Loss: 0.7148, Val Acc: 0.7500
# Epoch 19/30 | Train Loss: 0.8143, Train Acc: 0.7142 | Val Loss: 0.6929, Val Acc: 0.7548
# Epoch 20/30 | Train Loss: 0.8107, Train Acc: 0.7142 | Val Loss: 0.7302, Val Acc: 0.7424
# Epoch 21/30 | Train Loss: 0.8037, Train Acc: 0.7175 | Val Loss: 0.7158, Val Acc: 0.7464
# Epoch 22/30 | Train Loss: 0.8007, Train Acc: 0.7190 | Val Loss: 0.6928, Val Acc: 0.7548
# Epoch 23/30 | Train Loss: 0.7875, Train Acc: 0.7258 | Val Loss: 0.6844, Val Acc: 0.7582
# Epoch 24/30 | Train Loss: 0.7791, Train Acc: 0.7288 | Val Loss: 0.6865, Val Acc: 0.7588
# Epoch 25/30 | Train Loss: 0.7709, Train Acc: 0.7296 | Val Loss: 0.7038, Val Acc: 0.7496
# Epoch 26/30 | Train Loss: 0.7634, Train Acc: 0.7312 | Val Loss: 0.6671, Val Acc: 0.7698
# Epoch 27/30 | Train Loss: 0.7583, Train Acc: 0.7332 | Val Loss: 0.6574, Val Acc: 0.7710
# Epoch 28/30 | Train Loss: 0.7557, Train Acc: 0.7350 | Val Loss: 0.6506, Val Acc: 0.7686
# Epoch 29/30 | Train Loss: 0.7494, Train Acc: 0.7375 | Val Loss: 0.6550, Val Acc: 0.7672
# Epoch 30/30 | Train Loss: 0.7423, Train Acc: 0.7416 | Val Loss: 0.6631, Val Acc: 0.7746
# Best Val Acc: 0.7746
# Saved: results/training_curves.png

# %% [markdown]
# ### Evaluation

# %%
test_loss, test_acc = evaluate(model, test_loader, criterion, device)
print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 0.6587 | Test Acc: 0.7744

# %%
@torch.no_grad()
def collect_predictions(model, loader, device):
    model.eval()
    all_preds, all_labels = [], []

    for images, labels in loader:
        images = images.to(device)
        outputs = model(images)
        preds = outputs.argmax(dim=1).cpu()

        all_preds.append(preds)
        all_labels.append(labels)

    return torch.cat(all_preds), torch.cat(all_labels)

all_preds, all_labels = collect_predictions(model, test_loader, device)

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(7, 6))
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
plt.tight_layout()

plt.savefig(f"{RESULTS_DIR}/confusion_matrix.png", dpi=200, bbox_inches="tight")
plt.show()

print("Saved:", f"{RESULTS_DIR}/confusion_matrix.png")

print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
# Saved: results/confusion_matrix.png
#               precision    recall  f1-score   support
#
#     airplane       0.79      0.78      0.78      1000
#   automobile       0.83      0.92      0.88      1000
#         bird       0.74      0.61      0.67      1000
#          cat       0.62      0.61      0.62      1000
#         deer       0.77      0.71      0.74      1000
#          dog       0.71      0.68      0.69      1000
#         frog       0.76      0.89      0.82      1000
#        horse       0.82      0.81      0.82      1000
#         ship       0.90      0.85      0.88      1000
#        truck       0.79      0.88      0.84      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000

# %% [markdown]
# ### Save Model and Weights

# %%
torch.save(model.state_dict(), f"{MODELS_DIR}/cifar10_cnn_best.pth")
print("Saved:", f"{MODELS_DIR}/cifar10_cnn_best.pth")
# Out:
# Saved: models/cifar10_cnn_best.pth
